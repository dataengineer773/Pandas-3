# %% [markdown]
# # Pandas
#
# [Pandas](https://pandas.pydata.org/) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# ### Installation:
#
# <div class="alert alert-block alert-warning">
# $ pip install pandas
# </div>

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series
#
# Defining a Series

# %%
s = pd.Series([4, 7, -5, 3])

# %%
s
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
s[2]
# Out:
# -5

# %%
s.values
# Out:
# array([ 4,  7, -5,  3])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s1 = pd.Series([1, 4, -3, 9], index=['a', 'b', 'c', 'd'])

# %%
s1['d']
# Out:
# 9

# %%
s1.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s1['d'] = -1

# %%
s1
# Out:
# a    1
# b    4
# c   -3
# d   -1
# dtype: int64

# %%
s1[['a', 'd']]
# Out:
# a    1
# d   -1
# dtype: int64

# %%
s1[s1>0]
# Out:
# a    1
# b    4
# dtype: int64

# %%
s2 = pd.Series(np.random.randint(10, 100, (10, )),
               pd.date_range(start='2022-12-01 08:00:00', periods=10, freq='1BH'))

# %%
s2
# Out:
# 2022-12-01 09:00:00    27
# 2022-12-01 10:00:00    32
# 2022-12-01 11:00:00    35
# 2022-12-01 12:00:00    94
# 2022-12-01 13:00:00    97
# 2022-12-01 14:00:00    57
# 2022-12-01 15:00:00    97
# 2022-12-01 16:00:00    22
# 2022-12-02 09:00:00    28
# 2022-12-02 10:00:00    30
# Freq: BH, dtype: int64

# %% [markdown]
# # DataFrame
#
# Defining a DataFrame using dictionary

# %%
data_dic = {'Tehran': [10000, 12000, 15000, 20000],
            'Esfahan': [3000, 4500, 8000, 9000],
            'Shiraz':[2000, 3000, 4700, 8500]}

df = pd.DataFrame(data_dic)

# %%
df
# Out:
#    Tehran  Esfahan  Shiraz
# 0   10000     3000    2000
# 1   12000     4500    3000
# 2   15000     8000    4700
# 3   20000     9000    8500

# %%
arr = np.random.randint(10, 1000, (100, 6))

# %%
df = pd.DataFrame(arr, columns=['f1', 'f2', 'f3', 'f4', 'f5', 'f6'])
# df = pd.DataFrame(arr, columns=[1, 2, 3, 4, 5, 6])

# %%
df
# Out:
#      f1   f2   f3   f4   f5   f6
# 0   484  946  522  164  243  984
# 1   264  850  133  736  834  764
# 2   594  309  368  326   95  545
# 3    73  327  857  785  944  796
# 4   488  571  732  408  825  710
# ..  ...  ...  ...  ...  ...  ...
# 95  639  126  968  692  352  679
# 96  492  320  387   37  983  944
# 97  535  736   85  484  988  420
# 98   46  732   52  687  988  558
# 99  174  192  444  684  174   85
#
# [100 rows x 6 columns]

# %% [markdown]
# # Viewing data
#
# + head, tail, and sample
# + index and columns
# + to_numpy
# + describe and info
# + sorting

# %%
df.head(10)
# Out:
#     f1   f2   f3   f4   f5   f6
# 0  484  946  522  164  243  984
# 1  264  850  133  736  834  764
# 2  594  309  368  326   95  545
# 3   73  327  857  785  944  796
# 4  488  571  732  408  825  710
# 5  416  913  562  320  115  392
# 6  752  101  680  575   54  691
# 7  704  173  439  422  108  792
# 8  734  679  177   95   69  621
# 9  697  156  787  867  164  513

# %%
df.tail(10)
# Out:
#      f1   f2   f3   f4   f5   f6
# 90  267  633  290  783  365  412
# 91  865  515  199  572  806  541
# 92  195  400   54  817  975   32
# 93  328  112  891  661  710  542
# 94  804  823  481  706  236   59
# 95  639  126  968  692  352  679
# 96  492  320  387   37  983  944
# 97  535  736   85  484  988  420
# 98   46  732   52  687  988  558
# 99  174  192  444  684  174   85

# %%
df.sample(10)
# Out:
#      f1   f2   f3   f4   f5   f6
# 2   594  309  368  326   95  545
# 20  296  434  425   19  534  811
# 12  307  595  956  436  940  247
# 61  934  321  142  714  780  299
# 60  486  152  840  162  440  564
# 8   734  679  177   95   69  621
# 72  455  223   82   25  969  250
# 77  471  688  313  142  322   74
# 29  804  803   42  228  301  668
# 1   264  850  133  736  834  764

# %%
df.columns
# Out:
# Index(['f1', 'f2', 'f3', 'f4', 'f5', 'f6'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df['f3']
# Out:
# 0     522
# 1     133
# 2     368
# 3     857
# 4     732
#      ...
# 95    968
# 96    387
# 97     85
# 98     52
# 99    444
# Name: f3, Length: 100, dtype: int64

# %%
df1 = df.copy()

# %%
df1.index = ['0'+str(i) for i in range(100)]

# %%
df1
# Out:
#       f1   f2   f3   f4   f5   f6
# 00   484  946  522  164  243  984
# 01   264  850  133  736  834  764
# 02   594  309  368  326   95  545
# 03    73  327  857  785  944  796
# 04   488  571  732  408  825  710
# ..   ...  ...  ...  ...  ...  ...
# 095  639  126  968  692  352  679
# 096  492  320  387   37  983  944
# 097  535  736   85  484  988  420
# 098   46  732   52  687  988  558
# 099  174  192  444  684  174   85
#
# [100 rows x 6 columns]

# %%
df[['f3', 'f5']]
# Out:
#      f3   f5
# 0   522  243
# 1   133  834
# 2   368   95
# 3   857  944
# 4   732  825
# ..  ...  ...
# 95  968  352
# 96  387  983
# 97   85  988
# 98   52  988
# 99  444  174
#
# [100 rows x 2 columns]

# %%
df
# Out:
#      f1   f2   f3   f4   f5   f6
# 0   484  946  522  164  243  984
# 1   264  850  133  736  834  764
# 2   594  309  368  326   95  545
# 3    73  327  857  785  944  796
# 4   488  571  732  408  825  710
# ..  ...  ...  ...  ...  ...  ...
# 95  639  126  968  692  352  679
# 96  492  320  387   37  983  944
# 97  535  736   85  484  988  420
# 98   46  732   52  687  988  558
# 99  174  192  444  684  174   85
#
# [100 rows x 6 columns]

# %%
df.loc[1, :]
# Out:
# f1    264
# f2    850
# f3    133
# f4    736
# f5    834
# f6    764
# Name: 1, dtype: int64

# %%
df.loc[1, 'f1']
# Out:
# 264

# %%
df1.loc['01', 'f5']
# Out:
# 834

# %%
df1.iloc[1, 4]
# Out:
# 834

# %%
df1.iloc[3:11, [1, 5, 2]]
# Out:
#       f2   f6   f3
# 03   327  796  857
# 04   571  710  732
# 05   913  392  562
# 06   101  691  680
# 07   173  792  439
# 08   679  621  177
# 09   156  513  787
# 010   69  353  860

# %%
df.loc[2]
# Out:
# f1    594
# f2    309
# f3    368
# f4    326
# f5     95
# f6    545
# Name: 2, dtype: int64

# %%
G = ['M', 'F']
df['G'] = [G[np.random.randint(0, 2)] for _ in range(100)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   f1      100 non-null    int64
#  1   f2      100 non-null    int64
#  2   f3      100 non-null    int64
#  3   f4      100 non-null    int64
#  4   f5      100 non-null    int64
#  5   f6      100 non-null    int64
#  6   G       100 non-null    object
# dtypes: int64(6), object(1)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#                f1          f2          f3         f4         f5          f6
# count  100.000000  100.000000  100.000000  100.00000  100.00000  100.000000
# mean   510.720000  524.590000  484.920000  473.59000  510.58000  523.630000
# std    285.721807  294.301882  297.994328  276.55343  317.09267  284.628862
# min     23.000000   15.000000   38.000000   11.00000   28.00000   11.000000
# 25%    294.500000  298.250000  216.000000  221.50000  201.75000  264.500000
# 50%    490.000000  509.500000  465.000000  502.50000  495.00000  543.500000
# 75%    749.750000  782.750000  756.500000  669.00000  801.00000  746.750000
# max    984.000000  998.000000  991.000000  988.00000  998.00000  996.000000

# %%
df.sort_values(by=['f1', 'f3'], ascending=False)
# Out:
#      f1   f2   f3   f4   f5   f6  G
# 17  984  765  127  330  979  437  F
# 63  982  355  807  844  908  555  F
# 50  974  444  255  123  293  525  F
# 86  973  776  991  523  101  923  M
# 65  966  996  718  761  185  890  M
# ..  ...  ...  ...  ...  ...  ... ..
# 28   47  894  813  659  633  152  M
# 98   46  732   52  687  988  558  F
# 10   42   69  860  187  966  353  M
# 64   42  944  316  664  870  197  F
# 76   23   15  721  271   55  149  M
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Dealing with missing data

# %%
df1 = df.copy()

# %%
np.random.random(df1.shape)
# Out:
# array([[0.95060381, 0.26954209, 0.09633576, 0.86577393, 0.91926954,
#         0.73593583, 0.31620523],
#        [0.53697407, 0.97188413, 0.85717678, 0.3423249 , 0.78975734,
#         0.42518906, 0.18133731],
#        [0.66943757, 0.69006312, 0.35983225, 0.84377699, 0.97084595,
#         0.52070434, 0.26343818],
#        [0.65610267, 0.4584138 , 0.30766117, 0.54670913, 0.11895322,
#         0.83039926, 0.75577953],
#        [0.60467841, 0.10264371, 0.46795954, 0.11389435, 0.95773767,
#         0.99702064, 0.23329704],
#        [0.8916638 , 0.07998595, 0.25408182, 0.81053843, 0.92471116,
#         0.56380222, 0.05588097],
#        [0.96671678, 0.74714105, 0.35126562, 0.18443493, 0.5957982 ,
#         0.95214972, 0.3601463 ],
#        [0.32687657, 0.06535774, 0.33030551, 0.10538914, 0.41881382,
#         0.86640116, 0.03724397],
#        [0.96781562, 0.47121424, 0.55694269, 0.50775401, 0.67327446,
#         0.4425728 , 0.52129042],
#        [0.58176467, 0.99963089, 0.4197213 , 0.0052643 , 0.1124973 ,
#         0.73198221, 0.98341744],
#        [0.33294801, 0.76322335, 0.45462537, 0.16793855, 0.45964745,
#         0.85129972, 0.67792283],
#        [0.88771067, 0.05724069, 0.82285758, 0.76719978, 0.55808999,
#         0.19118322, 0.69011168],
#        [0.79052901, 0.41574226, 0.55932047, 0.7279963 , 0.84163366,
#         0.10704674, 0.44483276],
#        [0.47437855, 0.12023117, 0.80268607, 0.33289577, 0.97781289,
#         0.36861828, 0.42682134],
#        [0.04714482, 0.51858912, 0.94437836, 0.56796604, 0.7663771 ,
#         0.63130823, 0.92061358],
#        [0.09902316, 0.52503297, 0.60839316, 0.82510275, 0.31395282,
#         0.87578295, 0.46199324],
#        [0.7927952 , 0.19675571, 0.98287153, 0.04492093, 0.1361417 ,
#         0.70482267, 0.72586766],
#        [0.56092133, 0.46899354, 0.7684714 , 0.44828311, 0.13176639,
#         0.43567408, 0.71795764]])

# %%
from random import choice

# %%
sample(list(df1.columns), k=1)
# Out:
# ['f1']

# %%
for i in np.random.randint(0, 100, (20)):
    df1.loc[i, choice(list(df1.columns))] = None

# %%
df1
# Out:
#        f1     f2     f3     f4     f5     f6  G
# 0   484.0  946.0  522.0  164.0  243.0  984.0  F
# 1   264.0  850.0  133.0  736.0  834.0  764.0  F
# 2   594.0  309.0  368.0  326.0   95.0  545.0  M
# 3    73.0  327.0  857.0  785.0  944.0  796.0  F
# 4   488.0  571.0  732.0  408.0  825.0  710.0  F
# ..    ...    ...    ...    ...    ...    ... ..
# 95  639.0  126.0  968.0  692.0  352.0  679.0  M
# 96  492.0  320.0  387.0   37.0  983.0  944.0  M
# 97  535.0  736.0   85.0  484.0  988.0  420.0  F
# 98   46.0  732.0   52.0  687.0  988.0  558.0  F
# 99  174.0  192.0    NaN  684.0  174.0   85.0  F
#
# [100 rows x 7 columns]

# %%
df1.isna().sum()
# Out:
# f1    3
# f2    1
# f3    4
# f4    3
# f5    5
# f6    1
# G     3
# dtype: int64

# %%
df1[df1['f1'].isna()]
# Out:
#     f1     f2     f3     f4     f5     f6  G
# 32 NaN  550.0  680.0  555.0   36.0  581.0  F
# 71 NaN  504.0   92.0  594.0  630.0  900.0  F
# 87 NaN  851.0  968.0  140.0  547.0  623.0  F

# %%
df1[df1['f2'].isna()]
# Out:
#        f1  f2     f3     f4  f5     f6  G
# 31  103.0 NaN  852.0  872.0 NaN  940.0  M

# %%
df1[df1['f3'].isna()]
# Out:
#        f1     f2  f3     f4     f5     f6  G
# 22  635.0  487.0 NaN  109.0  784.0  855.0  F
# 27  432.0  839.0 NaN  454.0  307.0  180.0  M
# 72  455.0  223.0 NaN   25.0  969.0  250.0  M
# 99  174.0  192.0 NaN  684.0  174.0   85.0  F

# %%
df1.dropna()
# Out:
#        f1     f2     f3     f4     f5     f6  G
# 0   484.0  946.0  522.0  164.0  243.0  984.0  F
# 1   264.0  850.0  133.0  736.0  834.0  764.0  F
# 2   594.0  309.0  368.0  326.0   95.0  545.0  M
# 3    73.0  327.0  857.0  785.0  944.0  796.0  F
# 4   488.0  571.0  732.0  408.0  825.0  710.0  F
# ..    ...    ...    ...    ...    ...    ... ..
# 94  804.0  823.0  481.0  706.0  236.0   59.0  F
# 95  639.0  126.0  968.0  692.0  352.0  679.0  M
# 96  492.0  320.0  387.0   37.0  983.0  944.0  M
# 97  535.0  736.0   85.0  484.0  988.0  420.0  F
# 98   46.0  732.0   52.0  687.0  988.0  558.0  F
#
# [81 rows x 7 columns]

# %%
df1.fillna(-1)
# Out:
#        f1     f2     f3     f4     f5     f6  G
# 0   484.0  946.0  522.0  164.0  243.0  984.0  F
# 1   264.0  850.0  133.0  736.0  834.0  764.0  F
# 2   594.0  309.0  368.0  326.0   95.0  545.0  M
# 3    73.0  327.0  857.0  785.0  944.0  796.0  F
# 4   488.0  571.0  732.0  408.0  825.0  710.0  F
# ..    ...    ...    ...    ...    ...    ... ..
# 95  639.0  126.0  968.0  692.0  352.0  679.0  M
# 96  492.0  320.0  387.0   37.0  983.0  944.0  M
# 97  535.0  736.0   85.0  484.0  988.0  420.0  F
# 98   46.0  732.0   52.0  687.0  988.0  558.0  F
# 99  174.0  192.0   -1.0  684.0  174.0   85.0  F
#
# [100 rows x 7 columns]

# %% [markdown]
# # Operations
#
# + mean
# + std
# + apply

# %%
df.mean(numeric_only=True)
# Out:
# f1    510.72
# f2    524.59
# f3    484.92
# f4    473.59
# f5    510.58
# f6    523.63
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# f1    490.0
# f2    509.5
# f3    465.0
# f4    502.5
# f5    495.0
# f6    543.5
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# f1    285.721807
# f2    294.301882
# f3    297.994328
# f4    276.553430
# f5    317.092670
# f6    284.628862
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# f1     81636.951111
# f2     86613.597879
# f3     88800.619798
# f4     76481.799899
# f5    100547.761212
# f6     81013.588990
# dtype: float64

# %%
df.quantile(0.9, numeric_only=True)
# Out:
# f1    894.1
# f2    937.7
# f3    886.5
# f4    857.1
# f5    946.2
# f6    913.1
# Name: 0.9, dtype: float64

# %%
df.min()
# Out:
# f1    23
# f2    15
# f3    38
# f4    11
# f5    28
# f6    11
# G      F
# dtype: object

# %%
df.max()
# Out:
# f1    984
# f2    998
# f3    991
# f4    988
# f5    998
# f6    996
# G       M
# dtype: object

# %%
df.apply(lambda x: len(x))
# Out:
# f1    100
# f2    100
# f3    100
# f4    100
# f5    100
# f6    100
# G     100
# dtype: int64

# %%
def f(x):
    if x.dtype != 'object':
        return x - x.min()
    else:
        return x

# %%
df
# Out:
#      f1   f2   f3   f4   f5   f6  G
# 0   484  946  522  164  243  984  F
# 1   264  850  133  736  834  764  F
# 2   594  309  368  326   95  545  M
# 3    73  327  857  785  944  796  F
# 4   488  571  732  408  825  710  F
# ..  ...  ...  ...  ...  ...  ... ..
# 95  639  126  968  692  352  679  M
# 96  492  320  387   37  983  944  M
# 97  535  736   85  484  988  420  F
# 98   46  732   52  687  988  558  F
# 99  174  192  444  684  174   85  F
#
# [100 rows x 7 columns]

# %%
df.apply(f).min()
# Out:
# f1    0
# f2    0
# f3    0
# f4    0
# f5    0
# f6    0
# G     F
# dtype: object

# %% [markdown]
# # Merging
#
# + concat
# + merge
# + append
# + join

# %%
df1 = pd.DataFrame(np.random.randint(0, 10, (10, 5)), columns=['f1', 'f2', 'f3', 'f4', 'f5'])

# df2 = pd.DataFrame(np.random.randint(0, 10, (10, 5)), columns=['f1', 'f2', 'f3', 'f4', 'f5'])
df2 = pd.DataFrame(np.random.randint(0, 10, (10, 4)), columns=['f1', 'f2', 'f3', 'f4'])

# %%
df1
# Out:
#    f1  f2  f3  f4  f5
# 0   4   6   8   6   5
# 1   7   7   8   6   7
# 2   1   3   0   3   4
# 3   2   1   8   1   4
# 4   0   8   6   6   1
# 5   1   8   2   5   7
# 6   0   9   6   9   6
# 7   1   9   6   2   8
# 8   9   7   6   2   5
# 9   3   0   7   5   7

# %%
df2
# Out:
#    f1  f2  f3  f4
# 0   7   3   8   7
# 1   0   3   8   1
# 2   9   0   2   0
# 3   2   0   2   9
# 4   9   7   5   2
# 5   3   9   5   1
# 6   2   7   9   1
# 7   7   0   4   7
# 8   4   3   5   2
# 9   8   7   7   2

# %%
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#     f1  f2  f3  f4   f5
# 0    4   6   8   6  5.0
# 1    7   7   8   6  7.0
# 2    1   3   0   3  4.0
# 3    2   1   8   1  4.0
# 4    0   8   6   6  1.0
# 5    1   8   2   5  7.0
# 6    0   9   6   9  6.0
# 7    1   9   6   2  8.0
# 8    9   7   6   2  5.0
# 9    3   0   7   5  7.0
# 10   7   3   8   7  NaN
# 11   0   3   8   1  NaN
# 12   9   0   2   0  NaN
# 13   2   0   2   9  NaN
# 14   9   7   5   2  NaN
# 15   3   9   5   1  NaN
# 16   2   7   9   1  NaN
# 17   7   0   4   7  NaN
# 18   4   3   5   2  NaN
# 19   8   7   7   2  NaN

# %%
df1 = pd.DataFrame({'name': ['Amir', 'Danial', 'Deli', 'Sahar', 'Ali', 'Hosein'],
                    'age': [26, 2, 27, 23, 34, 19]})

df2 = pd.DataFrame({'name': ['Amir', 'Deli', 'Sahar', 'Ali', 'Hosein'],
                    'height': [180, 170, 150, 167, 183],
                    'wight': [67, 53, 78, 81, 79]})

# %%
df1
# Out:
#      name  age
# 0    Amir   26
# 1  Danial    2
# 2    Deli   27
# 3   Sahar   23
# 4     Ali   34
# 5  Hosein   19

# %%
df2
# Out:
#      name  height  wight
# 0    Amir     180     67
# 1    Deli     170     53
# 2   Sahar     150     78
# 3     Ali     167     81
# 4  Hosein     183     79

# %%
pd.merge(df1, df2, on='name')
# Out:
#      name  age  height  wight
# 0    Amir   26     180     67
# 1    Deli   27     170     53
# 2   Sahar   23     150     78
# 3     Ali   34     167     81
# 4  Hosein   19     183     79

# %%
df1.join(df2.set_index('name'), on='name')
# Out:
#      name  age  height  wight
# 0    Amir   26   180.0   67.0
# 1  Danial    2     NaN    NaN
# 2    Deli   27   170.0   53.0
# 3   Sahar   23   150.0   78.0
# 4     Ali   34   167.0   81.0
# 5  Hosein   19   183.0   79.0

# %% [markdown]
# # Reading and Writing
#
# + read_csv and to_csv
# + read_excel

# %%
df = pd.DataFrame(np.random.randint(0, 10, (100, 5)), 
                  columns=['f1', 'f2', 'f3', 'f4', 'f5'])

# %%
df.to_csv('sample.csv')

# %%
pd.read_csv('sample.csv', index_col=0)
# Out:
#     f1  f2  f3  f4  f5
# 0    7   8   5   3   1
# 1    4   4   2   8   6
# 2    7   7   4   9   7
# 3    5   2   6   0   9
# 4    3   1   8   5   5
# ..  ..  ..  ..  ..  ..
# 95   5   1   2   5   7
# 96   6   4   3   7   4
# 97   0   0   8   2   9
# 98   3   7   9   6   9
# 99   1   2   6   5   9
#
# [100 rows x 5 columns]

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %%
pd.read_excel('data.xlsx', engine='openpyxl')
# Out:
#    f1  f2  f3  f4
# 0   1   2   3   4
# 1  -1  -2  -3  -4
# 2  -1   1  -1   1
# 3   0   1   1   0

# %%
df = pd.read_excel('Professors.xlsx', engine='openpyxl')

# %%
df.columns
# Out:
# Index(['university', 'teacher', 'group', 'number_reacerch_plans',
#        'self_citation', ' h_index scopus ', 'article_scopus',
#        'number_Co_authors_scopus', 'article_scopus_2021',
#        'article_scopus_2021_in_total', 'citation_scopus',
#        'citation_scopus_2021', 'citation_scopus_2021_in_total', ' 10i_scopus',
#        ' h_index_google_scholar', 'article_google_scholar',
#        'number_Co_authors_google_scholar', 'article_google_scholar_2021',
#        'article_google_scholar_2021_in_total', 'citation_google_scholar',
#        'citation_google_scholar_2021', 'citation_google_scholar_2021_in_total',
#        '10i_google_scholar', 'farsi article in confrence',
#        'latin article in confrence', 'total_confrence', 'number_field work',
#        'book_written or translated', 'farsi_article_printed',
#        'latin_article_printed', 'foreign_education', 'international_teaching',
#        'article_Co_authors_international_scopus',
#        'article_international_scopus_in_total', 'international_confrence',
#        'international_confrence_in_total', 'mark_science', 'honors_received',
#        'membership_science', 'study_and_teach'],
#       dtype='object')

# %%
df.nunique()
# Out:
# university                                   36
# teacher                                    1102
# group                                         5
# number_reacerch_plans                        20
# self_citation                                78
#  h_index scopus                              38
# article_scopus                              121
# number_Co_authors_scopus                    101
# article_scopus_2021                          26
# article_scopus_2021_in_total                221
# citation_scopus                             383
# citation_scopus_2021                        157
# citation_scopus_2021_in_total               627
#  10i_scopus                                  35
#  h_index_google_scholar                      44
# article_google_scholar                      173
# number_Co_authors_google_scholar             58
# article_google_scholar_2021                  37
# article_google_scholar_2021_in_total        320
# citation_google_scholar                     476
# citation_google_scholar_2021                213
# citation_google_scholar_2021_in_total       695
# 10i_google_scholar                           73
# farsi article in confrence                   45
# latin article in confrence                   58
# total_confrence                              73
# number_field work                            11
# book_written or translated                   16
# farsi_article_printed                        39
# latin_article_printed                       116
# foreign_education                             3
# international_teaching                        3
# article_Co_authors_international_scopus      50
# article_international_scopus_in_total       259
# international_confrence                      32
# international_confrence_in_total            176
# mark_science                                  4
# honors_received                              15
# membership_science                           12
# study_and_teach                               4
# dtype: int64
